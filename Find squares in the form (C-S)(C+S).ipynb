# %%
import numpy as np

# %%
for s in range(1,20):
    for c in range(1,20):
        if ((c-s)*(c+s) + s**2) == c**2:
            print "(%d-%d)*(%d+%d) + %d = %d" % (c,s,c,s, s**2, c**2)
# Out:
# (1-1)*(1+1) + 1 = 1
# (2-1)*(2+1) + 1 = 4
# (3-1)*(3+1) + 1 = 9
# (4-1)*(4+1) + 1 = 16
# (5-1)*(5+1) + 1 = 25
# (6-1)*(6+1) + 1 = 36
# (7-1)*(7+1) + 1 = 49
# (8-1)*(8+1) + 1 = 64
# (9-1)*(9+1) + 1 = 81
# (10-1)*(10+1) + 1 = 100
# (11-1)*(11+1) + 1 = 121
# (12-1)*(12+1) + 1 = 144
# (13-1)*(13+1) + 1 = 169
# (14-1)*(14+1) + 1 = 196
# (15-1)*(15+1) + 1 = 225
# (16-1)*(16+1) + 1 = 256
# (17-1)*(17+1) + 1 = 289
# (18-1)*(18+1) + 1 = 324
# (19-1)*(19+1) + 1 = 361
# (1-2)*(1+2) + 4 = 1
# (2-2)*(2+2) + 4 = 4
# (3-2)*(3+2) + 4 = 9
# (4-2)*(4+2) + 4 = 16
# (5-2)*(5+2) + 4 = 25
# (6-2)*(6+2) + 4 = 36
# (7-2)*(7+2) + 4 = 49
# (8-2)*(8+2) + 4 = 64
# (9-2)*(9+2) + 4 = 81
# (10-2)*(10+2) + 4 = 100
# (11-2)*(11+2) + 4 = 121
# (12-2)*(12+2) + 4 = 144
# (13-2)*(13+2) + 4 = 169
# (14-2)*(14+2) + 4 = 196
# (15-2)*(15+2) + 4 = 225
# (16-2)*(16+2) + 4 = 256
# (17-2)*(17+2) + 4 = 289
# (18-2)*(18+2) + 4 = 324
# (19-2)*(19+2) + 4 = 361
# (1-3)*(1+3) + 9 = 1
# (2-3)*(2+3) + 9 = 4
# (3-3)*(3+3) + 9 = 9
# ...
